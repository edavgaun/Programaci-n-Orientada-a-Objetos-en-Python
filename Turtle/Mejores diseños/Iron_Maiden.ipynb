# %%
# El presente trabajo fue creado por Carlos Alonso de Florida Ceballos
# Semestre de Ago-Dic 2019
# Logo de Iron Maiden


import turtle
drawing_area=turtle.Screen()
drawing_area.setup(width=1200, height=800)

t=turtle.Pen()
t.shape("arrow")

t.up()
t.speed(0)
t.color("black")
t.width(40)                 #width



t.rt(180)
t.fd(300)
t.rt(180)
"""
#caja
t.rt(180)
t.fd(300)
t.rt(180)
t.down()
t.fd(600)
t.rt(-90)
t.fd(100)
t.rt(-90)
t.fd(600)
t.rt(-90)
t.fd(100)
t.rt(-90)
#termina caja
#cuadricula
for x in range(10):
    t.fd(60)
    t.rt(-90)
    t.fd(100)
    t.rt(180)
    t.fd(100)
    t.rt(-90)
    
t.rt(180)
t.fd(600)
t.rt(180)
#termina cuadricula

#"""


t.down()
t.fd(20)
t.rt(180)
t.fd(20)
t.rt(180)

t.fillcolor('black')
t.begin_fill()
#i
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(100)
t.rt(-90)
t.end_fill()


t.up()
t.fd(5)
#r
t.down()
t.fillcolor('black')
t.begin_fill()
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(15)
t.rt(-135)
t.fd(20)
t.rt(100)
t.fd(38)
t.rt(70)
t.fd(40)
t.rt(-70)
t.fd(50)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(40)
t.rt(-145)
t.fd(16)
t.rt(90)
t.fd(22)
t.rt(90)
t.fd(65)
t.rt(90)
t.end_fill()
t.up()
t.fd(27)
t.rt(-40)

t.fillcolor('white')
t.begin_fill()
t.down()


t.fd(8)
t.rt(80)
t.fd(8)
t.rt(50)
t.rt(90)
t.fd(13)
t.up()
t.rt(-90)
t.fd(64)
t.end_fill()



#o
t.rt(-90)
t.fd(60)#dist entre r y o
t.rt(-90)
t.fd(100)
#empieza o
t.rt(-145)#angulo de la o
t.fd(4)

t.fillcolor('black')
t.begin_fill()
t.down()
t.fd(74)
t.rt(-75)
t.fd(45)
t.rt(-50)
t.fd(30)
t.rt(-52)
t.fd(45)
t.rt(-75)

t.fd(74)
t.rt(216)  #here
t.end_fill()

t.up()




t.fd(40)

#triangulo de la o
t.rt(30)

t.down()

t.fillcolor('white')
t.begin_fill()

t.fd(30)
t.rt(-1200)
t.fd(30)
t.rt(-120)#era 120
t.fd(30)
t.up()

t.end_fill()
t.rt(190)
t.fd(54)
t.rt(-67)
t.fd(45)
t.rt(-90)
t.fd(100)
t.rt(-90)
t.fd(50)
t.rt(180)
#espacio entre o y n
t.fd(15)
t.rt(88)#era 90                                     #now here
t.fd(7)#era 11
t.rt(-90)



t.down()
#n
t.fillcolor('black')
t.begin_fill()
t.fd(30)
t.rt(45)
t.fd(42)#diagonal
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(120)
t.rt(135)
t.fd(24)
t.rt(45)
t.fd(40)
t.rt(-45)
t.fd(42)
t.rt(-135)
t.fd(67)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(80)
t.rt(-45)
t.fd(29)
t.rt(135)
t.fd(10)
t.up()

t.end_fill()
t.fd(77)

#espacio entre iron y maiden
t.fd(40)












#m
t.down()

t.fillcolor('black')
t.begin_fill()
t.fd(30)
t.rt(45)
t.fd(30)#diagonal
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(30)#diagonal
t.rt(45)
t.fd(100)#fd
t.rt(135)
t.fd(30)

t.rt(45)
t.fd(65)#fd2
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(30)
t.rt(-135)
t.fd(65)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(85)
t.rt(-45)
t.fd(21)
t.rt(135)
t.fd(20)
t.up()
t.end_fill()

t.fd(80)

#a
#distancia entre m y a
t.fd(80)
t.rt(180)
t.fd(20)

t.fillcolor('black')
t.begin_fill()
t.down()



t.rt(180)
t.fd(30)
t.rt(90)
t.fd(100)
t.rt(90)
t.fd(45)

t.rt(55)
t.fd(30)
t.rt(-100)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)


t.rt(-80)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(15)
t.rt(-110)
t.fd(56)

t.end_fill()
t.up()
t.rt(145)
t.fd(40)
t.rt(35)
t.down()
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(110)
t.rt(-180)
t.fd(20)
t.rt(35)
t.rt(180)
t.fd(30)



t.rt(90)
t.up()
t.end_fill()

#i
t.fd(38)
t.rt(-90)
t.fd(-57)
t.down()
t.fillcolor('black')
t.begin_fill()
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(100)
t.rt(90)
t.fd(20)
t.end_fill()
t.up()
t.rt(180)
t.fd(30)
#d
t.down()
t.fillcolor('black')
t.begin_fill()
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(55)
t.fd(90)
t.rt(60)
t.fd(30)
t.rt(-25)
t.rt(90)
t.fd(59)
t.end_fill()

t.up()
t.rt(180)
t.fd(20)
t.rt(-90)
t.fd(40)
t.down()
t.fillcolor('white')
t.begin_fill()


t.fd(20)
t.rt(90)
t.rt(55)
t.fd(41)
t.rt(90)
t.rt(35)
t.fd(24)
t.rt(90)
t.fd(20)
t.end_fill()
t.up()


t.rt(180)
t.fd(46)
t.rt(-90)
t.fd(55)



#e
t.up()
t.rt(-90)
t.fd(100)
t.rt(180)
t.down()
t.fillcolor('black')
t.begin_fill()

t.fd(72)
t.rt(-35)
t.fd(35)
t.rt(-55)#
t.fd(40)
t.rt(-90)
t.fd(20)
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(-90)
t.fd(20)
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(-90)
t.fd(21)
t.rt(-90)
t.fd(60)
t.rt(180)
t.fd(40)


t.up()
#n
#espacio entre e y n
t.fd(30)
t.end_fill()

t.up()
t.down()
t.fillcolor('black')
t.begin_fill()

t.fd(30)
t.rt(45)
t.fd(42)#diagonal
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(120)
t.rt(135)
t.fd(24)
t.rt(45)
t.fd(40)
t.rt(-45)
t.fd(42)
t.rt(-135)
t.fd(67)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(80)
t.rt(-45)
t.fd(29)
t.rt(135)

t.end_fill()

#t.fd(10)
t.up()
t.fd(77)




t.up()
t.rt(180)
t.fd(680)
t.rt(-90)
t.fd(30)







import turtle
drawing_area=turtle.Screen()
drawing_area.setup(width=1200, height=800)

t=turtle.Pen()
t.shape("arrow")
t.pen(10)

t.up()
t.speed(0)
t.width(2) #width
t.color("white")
t.rt(180)
t.fd(300)
t.rt(180)
"""
#caja
t.rt(180)
t.fd(300)
t.rt(180)
t.down()
t.fd(600)
t.rt(-90)
t.fd(100)
t.rt(-90)
t.fd(600)
t.rt(-90)
t.fd(100)
t.rt(-90)
#termina caja
#cuadricula
for x in range(10):
    t.fd(60)
    t.rt(-90)
    t.fd(100)
    t.rt(180)
    t.fd(100)
    t.rt(-90)
    
t.rt(180)
t.fd(600)
t.rt(180)
#termina cuadricula

#"""





t.down()
t.fd(20)
t.rt(180)
t.fd(20)
t.rt(180)

t.fillcolor('red')
t.begin_fill()
#i
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(100)
t.rt(-90)
t.end_fill()


t.up()
t.fd(5)
#r
t.down()
t.fillcolor('red')
t.begin_fill()
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(15)
t.rt(-135)
t.fd(20)
t.rt(100)
t.fd(38)
t.rt(70)
t.fd(40)
t.rt(-70)
t.fd(50)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(40)
t.rt(-145)
t.fd(16)
t.rt(90)
t.fd(22)
t.rt(90)
t.fd(65)
t.rt(90)
t.end_fill()
t.up()
t.fd(27)
t.rt(-40)

t.fillcolor('black')
t.begin_fill()
t.down()


t.fd(8)
t.rt(80)
t.fd(8)
t.rt(50)
t.rt(90)
t.fd(13)
t.up()
t.rt(-90)
t.fd(64)
t.end_fill()



#o
t.rt(-90)
t.fd(60)#dist entre r y o
t.rt(-90)
t.fd(100)
#empieza o
t.rt(-145)#angulo de la o
t.fd(4)

t.fillcolor('red')
t.begin_fill()
t.down()
t.fd(74)
t.rt(-75)
t.fd(45)
t.rt(-50)
t.fd(30)
t.rt(-52)
t.fd(45)
t.rt(-75)

t.fd(74)
t.rt(216)  #here
t.end_fill()

t.up()




t.fd(40)

#triangulo de la o
t.rt(30)

t.down()

t.fillcolor('black')
t.begin_fill()

t.fd(30)
t.rt(-1200)
t.fd(30)
t.rt(-120)#era 120
t.fd(30)
t.up()

t.end_fill()
t.rt(190)
t.fd(54)
t.rt(-67)
t.fd(45)
t.rt(-90)
t.fd(100)
t.rt(-90)
t.fd(50)
t.rt(180)
#espacio entre o y n
t.fd(15)
t.rt(88)#era 90                                     #now here
t.fd(7)#era 11
t.rt(-90)



t.down()
#n
t.fillcolor('red')
t.begin_fill()
t.fd(30)
t.rt(45)
t.fd(42)#diagonal
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(120)
t.rt(135)
t.fd(24)
t.rt(45)
t.fd(40)
t.rt(-45)
t.fd(42)
t.rt(-135)
t.fd(67)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(80)
t.rt(-45)
t.fd(29)
t.rt(135)
t.fd(10)
t.up()

t.end_fill()
t.fd(77)

#espacio entre iron y maiden
t.fd(40)












#m
t.down()

t.fillcolor('red')
t.begin_fill()
t.fd(30)
t.rt(45)
t.fd(30)#diagonal
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(30)#diagonal
t.rt(45)
t.fd(100)#fd
t.rt(135)
t.fd(30)

t.rt(45)
t.fd(65)#fd2
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(30)
t.rt(-135)
t.fd(65)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(85)
t.rt(-45)
t.fd(21)
t.rt(135)
t.fd(20)
t.up()
t.end_fill()

t.fd(80)

#a
#distancia entre m y a
t.fd(80)
t.rt(180)
t.fd(20)

t.fillcolor('red')
t.begin_fill()
t.down()



t.rt(180)
t.fd(30)
t.rt(90)
t.fd(100)
t.rt(90)
t.fd(45)

t.rt(55)
t.fd(30)
t.rt(-100)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(20)


t.rt(-80)
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(15)
t.rt(-110)
t.fd(56)

t.end_fill()
t.up()
t.rt(145)
t.fd(40)
t.rt(35)
t.down()
t.fillcolor('black')
t.begin_fill()
t.fd(20)
t.rt(110)
t.rt(-180)
t.fd(20)
t.rt(35)
t.rt(180)
t.fd(30)



t.rt(90)
t.up()
t.end_fill()

#i
t.fd(38)
t.rt(-90)
t.fd(-57)
t.down()
t.fillcolor('red')
t.begin_fill()
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(100)
t.rt(90)
t.fd(20)
t.end_fill()
t.up()
t.rt(180)
t.fd(30)
#d
t.down()
t.fillcolor('red')
t.begin_fill()
t.rt(-90)
t.fd(100)
t.rt(90)
t.fd(20)
t.rt(55)
t.fd(90)
t.rt(60)
t.fd(30)
t.rt(-25)
t.rt(90)
t.fd(59)
t.end_fill()

t.up()
t.rt(180)
t.fd(20)
t.rt(-90)
t.fd(40)
t.down()
t.fillcolor('black')
t.begin_fill()


t.fd(20)
t.rt(90)
t.rt(55)
t.fd(41)
t.rt(90)
t.rt(35)
t.fd(24)
t.rt(90)
t.fd(20)
t.end_fill()
t.up()


t.rt(180)
t.fd(46)
t.rt(-90)
t.fd(55)



#e
t.up()
t.rt(-90)
t.fd(100)
t.rt(180)
t.down()
t.fillcolor('red')
t.begin_fill()

t.fd(72)
t.rt(-35)
t.fd(35)
t.rt(-55)#
t.fd(40)
t.rt(-90)
t.fd(20)
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(-90)
t.fd(20)
t.rt(-90)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(30)
t.rt(-90)
t.fd(21)
t.rt(-90)
t.fd(60)
t.rt(180)
t.fd(40)


t.up()
#n
#espacio entre e y n
t.fd(30)
t.end_fill()

t.up()
t.down()
t.fillcolor('red')
t.begin_fill()

t.fd(30)
t.rt(45)
t.fd(42)#diagonal
t.rt(-135)
t.fd(30)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(120)
t.rt(135)
t.fd(24)
t.rt(45)
t.fd(40)
t.rt(-45)
t.fd(42)
t.rt(-135)
t.fd(67)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(80)
t.rt(-45)
t.fd(29)
t.rt(135)

t.end_fill()

#t.fd(10)
t.up()
t.fd(77)




t.up()
t.rt(180)
t.fd(680)
t.rt(-90)
t.fd(30)

t.Screen().exitonclick()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-decf3374770d> in <module>
#     985 t.fd(30)
#     986
# --> 987 t.Screen().exitonclick()
#
# AttributeError: 'Turtle' object has no attribute 'Screen'
