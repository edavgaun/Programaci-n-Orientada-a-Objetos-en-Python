# %%
# El presente trabajo fue creado por Ana Kaiulani Lorenzo Quintana
# Semestre de Ago-Dic 2019
# Perro en el espacio


import turtle
turtle.Pen()
t=turtle
t.clear()
t.reset()
t.pensize(3)
t.color("dark blue")
RAD = 100
RAD2 = RAD / 2
RAD6 = RAD / 6
t.degrees() 
t.fd(200)
t.setheading(90)
t.fd(200*5/8)
t.circle(RAD, 40)
t.dot()
pos1=t.position()

t.right(-90-180)
t.circle(17,90)
antena=t.position()
antenah=t.heading()
t.circle(17,90)
t.circle(17,-180)
t.left(-90-180)





t.circle(RAD, 20)
t.dot()
pos2=t.position()

t.circle(RAD,175-60)
t.right(-75)
t.fd(150)
diagonalgrande=t.position()
t.right(180)
t.fillcolor("yellow")
t.begin_fill()
t.circle(16,110)
A1=t.position()

t.fd(25)
t.bk(25)
t.circle(16,250)
t.end_fill()


t.up()
t.goto(178.74,213.74)
t.setheading(130)
t.right(90)
t.down()
t.fd(15)
t.pensize(10)
t.dot()
t.pensize(7)
t.pencolor("red")
t.dot()
t.pencolor("dark blue")
t.pensize(3)


#Primera linea grande
t.up()
t.goto(0,0)
t.setheading(90)
t.down()
t.fillcolor("yellow")
t.begin_fill()
t.fd(30)
t.setheading(0)
t.fd(200)
t.setheading(-90)
t.fd(30)
t.end_fill()

#Segunda linea grande
t.up()
t.goto(0,0)
t.end_fill()
t.setheading(90)
t.down()
t.fd(30)
t.setheading(0)
t.fd(10)

t.setheading(90)
t.down()
t.fd(10)
t.setheading(0)
t.fd(190)
t.bk(200/8)
perro=t.position()



#Circulo del casco
t.setheading(125)

t.fd(50)
t.up()
t.right(-110)
t.fd(16)
t.pensize(6)
t.dot()
t.pencolor("red")
t.pensize(2)
t.dot()

t.up()
t.goto(175.00,40.00)



t.pencolor("dark blue")
t.pensize(3)
t.down()
t.setheading(90)
t.fd(200*3/8)
t.setheading(90)

t.circle(20, -180)
t.circle(20, 185)
t.circle(65, 180)
cabeza=t.position()

t.up()
t.fd(53/3)
t.dot()
t.fd(53/3)
t.dot()
t.right(135)
t.fd(53/3)
t.dot()
t.goto(cabeza)
t.setheading(-90)
t.down()


#Hocico
t.setheading(180)
t.fd(35)

t.circle(10, 90)
t.fd(5)
t.setheading(0)
t.fillcolor("light blue")
t.begin_fill()
t.circle(15,90)

t.setheading(180)
t.fd(5)
t.circle(10, 90)
t.end_fill()

t.fd(23)

t.circle(20, 90)
t.fd(40)
t.setheading(180+90)
t.fd(10)

t.up()
t.goto(0,0)


t.goto(0,0)
t.setheading(90)
t.fd(15)
t.setheading(0)
t.fd(20)
t.pencolor("dark blue")
t.pensize(6)
t.dot()
t.pencolor("red")
t.pensize(2)
t.dot()
for i in range (3):
    t.fd(53.3)
    t.pencolor("dark blue")
    t.pensize(6)
    t.dot()
    t.pencolor("red")
    t.pensize(2)
    t.dot()

t.up()
t.goto(80,120)
t.pencolor("dark blue")
t.pensize(5)
t.down()
t.dot()
t.setheading(90)
t.up()
t.fd(15)
t.down()
t.pensize(4)
t.setheading(45-180-45)
t.circle(20,-40)

t.Screen().exitonclick()
