# %%
# El presente trabajo fue creado por Rodrigo Loose Millares
# Semestre de Ago-Dic 2019
# Zorro

import turtle

t=turtle.Pen()
t.speed(8)
t.pensize(2)
# CABEZA

t.setheading(270)
t.circle(50)
t.setheading(180)
t.circle(50,-90)
t.setheading(270)
t.circle(50,-90)

# OREJA I
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,-30)
t.down()
t.setheading(100)
t.forward(50)
t.setheading(320)
t.forward(45)

t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,-30)
t.setheading(100)
t.forward(50)
t.setheading(250)
t.down()
t.circle(70,50)

# OREJA D
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,-120)
t.down()
t.setheading(40)
t.forward(50)
t.setheading(250)
t.forward(57)

t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,-120)
t.setheading(40)
t.forward(50)
t.down()
t.setheading(100)
t.circle(70,-52)

#Cara
t.up()
t.goto(0,0)
t.setheading(0)
t.forward(30)
t.dot(10)

t.forward(40)
t.dot(10)

t.back(20)
t.setheading(270)
t.forward(30)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)
t.forward(1)
t.dot(10)


# CUELLO
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,45)
t.setheading(200)
t.down()
t.circle(30,110)
t.forward(50)
t.left(270)
t.circle(100,-20)
t.setheading(30)
t.circle(60,81)

#CUERPO I D COLA
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,45)
t.setheading(200)
t.down()
t.circle(30,110)
t.setheading(200)
t.circle(60,130)
t.up()
t.circle(60,30)

t.up()
t.forward(4)

t.down()
t.forward(22)

t.up()
t.forward(10)


t.circle(60,22)
t.down()
t.circle(60,134)

t.circle(60,-90)
t.setheading(0)
t.circle(100,120)
t.setheading(180)
t.circle(100,80)

t.up()
t.circle(100,-50)

t.down()
t.setheading(270)
t.forward(30)
t.setheading(45)
t.forward(30)
t.setheading(270)
t.forward(30)
t.setheading(45)
t.forward(30)
t.setheading(270)
t.forward(30)
t.setheading(45)
t.forward(29)


#PATA I
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,45)
t.setheading(200)
t.down()
t.circle(30,110)

t.forward(10)
t.setheading(90)
t.circle(300, -15)
t.setheading(220)
t.circle(20,270)
t.setheading(90)
t.circle(4000, .85)

#PATA D
t.up()
t.goto(0,0)
t.setheading(270)
t.circle(50,45)
t.setheading(200)
t.down()

t.circle(30,110)
t.forward(50)
t.left(270)
t.circle(100,-20)

t.setheading(270)
t.circle(300,12)
t.setheading(160)
t.circle(20,-270)
t.setheading(90)
t.circle(4000, .9)


t.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e9356ce91fa6> in <module>
#     194
#     195
# --> 196 t.exitonclick()
#
# AttributeError: 'Turtle' object has no attribute 'exitonclick'
